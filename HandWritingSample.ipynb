# %%
#!pip install opencv-python
import pyrebase as pb
from PIL import Image
config = {
    "apiKey": "AIzaSyBbese4Fbh86KMXEciM8nD74Kc0yAEfG4g",
    "authDomain": "handwritingboard-f7d5e.firebaseapp.com",
    "databaseURL": "https://handwritingboard-f7d5e.firebaseio.com",
    "projectId": "handwritingboard-f7d5e",
    "storageBucket": "handwritingboard-f7d5e.appspot.com",
    "messagingSenderId": "1013504350423",
    "appId": "1:1013504350423:web:f0f49548b6958d9fe93892",
    "measurementId": "G-GT1SMHMNZB"
  };

firebase=pb.initialize_app(config)

db = firebase.database()

room=db.child("flag").get().val()

storage = firebase.storage()

print(room)



while room!="stop":
    
    if(room!="ideal"):
    
        storage.child(str(room)+"/"+str(room)+".jpg").download('Image','./'+str(room)+'.jpg')



        from PIL import Image
        def convertToPNG():
            img = Image.open(r"./"+room+".jpg") 
            img = img.convert("RGBA")
            datas = img.getdata()
            newData = []
            for item in datas:
                if item[0] == 255 and item[1] == 255 and item[2] == 255:
                    newData.append((255, 255, 255, 0))
                else:
                    newData.append(item)
            img.putdata(newData)
            img.save(r'./'+room+'.png', "PNG")#converted Image name
            print('Done')
    
#Transparency   
        import cv2
        img = cv2.imread('./'+room+'.jpg',2)
        print('a')
        ret, bw_img = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
        print('b')
#cv2.imshow("Binary Image",bw_img)

        cv2.imwrite('./'+room+'.jpg', bw_img)
        print('h')
#cv2.waitKey(0)
#cv2.destroyAllWindows()
        convertToPNG()



        s=storage.child(room+"/"+room+".jpg").put('./'+room+'.png')
        print(s.get("downloadTokens"))

        url=storage.child(room+"/"+room+".jpg").get_url(s.get("downloadTokens"))
        db.child(room).child("URI").set(url)
        db.child("flag").set("ideal")
    else:
        print("I am Ideal")
    room=db.child("flag").get().val()
    
    
print("done fully")
# Out:
# ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# I am Ideal
# ...

# %%
from PIL import Image
def convertToPNG():
    img = Image.open(r"./final.jpg") 
    img = img.convert("RGBA")
    datas = img.getdata()
    newData = []
    for item in datas:
        if item[0] == 255 and item[1] == 255 and item[2] == 255:
            newData.append((255, 255, 255, 0))
        else:
            newData.append(item)
    img.putdata(newData)
    img.save(r'./TransparentImage.png', "PNG")#converted Image name
    print('Done')
    
#Transparency   
import cv2
img = cv2.imread('./Surf.jpg',2)
print('a')
ret, bw_img = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
print('b')
#cv2.imshow("Binary Image",bw_img)

cv2.imwrite('./final.jpg', bw_img)
print('h')
#cv2.waitKey(0)
#cv2.destroyAllWindows()
convertToPNG()
print('c')
# Out:
# a
# b
# h
# Done
# c

# %%
import pyrebase as pb
#from PIL import Image
config = {
    "apiKey": "AIzaSyBbese4Fbh86KMXEciM8nD74Kc0yAEfG4g",
    "authDomain": "handwritingboard-f7d5e.firebaseapp.com",
    "databaseURL": "https://handwritingboard-f7d5e.firebaseio.com",
    "projectId": "handwritingboard-f7d5e",
    "storageBucket": "handwritingboard-f7d5e.appspot.com",
    "messagingSenderId": "1013504350423",
    "appId": "1:1013504350423:web:f0f49548b6958d9fe93892",
    "measurementId": "G-GT1SMHMNZB"
  };
# Out:
# KNK
